# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")   # type: ignore

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PYG_GRAPHS = torch.load("data/processed/pyg_graphs_384D.pt", weights_only=False)
# Out:
# PyTorch version: 2.5.1
# CUDA available: True
# CUDA version: 12.4

# %%
## HELPER FUNCTIONS FOR CREATING AND TRAINING MODEL
import importlib
import src.models.multitask_debate_gnn
importlib.reload(src.models.multitask_debate_gnn)

from src.models.multitask_debate_gnn import ECCConv, MultitaskDebateGNN, train_gnn_live, plot_cv_losses
from torch_geometric.nn import GCNConv, SAGEConv

from typing import Dict, Any, Type, Optional

def create_and_describe_model(model_args: Dict[str, Any], model_class: Type[MultitaskDebateGNN] = MultitaskDebateGNN) -> Optional[MultitaskDebateGNN]:
    """Build the model from args, print a summary, and return the instance (or None on failure)."""
    try:
        model = model_class(**model_args)
        print("Model created:")
        print(f"   Architecture: {[type(conv).__name__ for conv in model.convs]}")
        print(f"   Mode: {model.mode}")
        print(f"   Input dim: {model_args['in_dim']}")
        print(f"   Hidden dim: {model_args['hidden_dim']}")
        print(f"   Embedding dim: {model_args['emb_dim']}")
        print(f"   Number of layers: {model_args['num_layers']}")

        # Count parameters
        total_params = sum(p.numel() for p in model.parameters())
        trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
        print("\nModel Statistics:")
        print(f"   Total parameters: {total_params:,}")
        print(f"   Trainable parameters: {trainable_params:,}")
        print(f"   Model size: ~{total_params * 4 / 1024**2:.1f} MB")

        # Show model structure
        print("\nModel Structure:")
        print(model)
        return model

    except Exception as e:
        print(f"Error creating model: {e}")
        import traceback
        traceback.print_exc()
        return None
    
def run_cv_training(
    graph_data,
    model_args: dict,
    train_args: dict,
    model_class: Type[MultitaskDebateGNN] = MultitaskDebateGNN,
    live_plot: bool = False,):
    """
    Runs cross-validation training with cleanup and plotting.
    Returns (model, results, cv_history) or (None, None, None) on failure.
    """
    import gc, traceback
    import torch

    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    try:
        model, results, cv_history = train_gnn_live(
            all_graphs=getattr(graph_data, "pyg_graphs", graph_data),
            model_args=model_args,
            train_args=train_args,
            model_class=model_class,
            live_plot=live_plot,
        )
        plot_cv_losses(cv_history=cv_history)
        return model, results, cv_history
    except Exception as e:
        print(f"Training error: {e}")
        traceback.print_exc()
        return None, None, None

# %%
MODEL_ARGS = dict(
    in_dim = 384,
    hidden_dim = 256,
    emb_dim = 128,
    neg_attr_weight = 0.3,
    dropout = 0.15,
    num_layers=3,
    mode="full",
    conv_cls_list=[SAGEConv, SAGEConv, ECCConv],
    ecc_kwargs=dict(
        edge_mlp_dropout=0.1,
        keep_prob=0.8,
        conf_dim=1,
        stance_dim=3
    )
)

TRAIN_ARGS = dict(
    epochs = 30,
    lr = 0.001,
    patience = 6,
    min_delta = 3e-4,
    neg_sample_ratio = 0.5,
    temp_reg_weight = 0.1,
    val_n_last = 1, # or val_pct_last = k (pick either one)
    # val_pct_last = 0.1,
    # val_gap_n = 1,
    task_weights = {"link": 1.0, "conf": 1.0, "stance": 1.0}
)

# See created model
_ = create_and_describe_model(MODEL_ARGS)
# Out:
# Model created:
#    Architecture: ['SAGEConv', 'SAGEConv', 'ECCConv']
#    Mode: full
#    Input dim: 384
#    Hidden dim: 256
#    Embedding dim: 128
#    Number of layers: 3
#
# Model Statistics:
#    Total parameters: 4,741,704
#    Trainable parameters: 4,741,704
#    Model size: ~18.1 MB
#
# Model Structure:
# MultitaskDebateGNN(
#   (convs): ModuleList(
#     (0): SAGEConv(384, 256, aggr=mean)
#     (1): SAGEConv(256, 256, aggr=mean)
#     (2): ECCConv(256, 128)
#   )
#   (norms): ModuleList(
#     (0-1): 2 x LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (activation): GELU(approximate='none')
#   (dropout): Dropout(p=0.15, inplace=False)
#   (skip): Linear(in_features=384, out_features=128, bias=True)
#   (link_head): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.15, inplace=False)
#     (3): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (edge_head): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=256, out_features=4, bias=True)
#   )
# )

# %%
import numpy as np
import pandas as pd
import torch
from collections import defaultdict
from copy import deepcopy


def gap_ablation_test_means(
    gaps,
    repeats=1,
    train_args_base=None,
    model_args=None,
    graph_data=None,
    seed_base=42,
    save_csv="results/gap_ablation_test_means.csv",
):
    """
    Run gap ablation, average test metrics across folds and repeats.
    Produces a table with per-gap metric means in the specified column order.
    """
    assert train_args_base is not None and model_args is not None and graph_data is not None

    records = {g: defaultdict(list) for g in gaps}

    for g in gaps:
        for r in range(repeats):
            seed = seed_base + r
            np.random.seed(seed)
            torch.manual_seed(seed)
            if torch.cuda.is_available():
                torch.cuda.manual_seed_all(seed)

            ta = deepcopy(train_args_base)
            ta["val_gap_n"] = int(g)
            print(f"[gap={g}] repeat {r+1}/{repeats} seed={seed}")
            _, results, _ = run_cv_training(
                graph_data=graph_data,
                model_args=model_args,
                train_args=ta,
                model_class=MultitaskDebateGNN,
                live_plot=False,
            )

            if not results:
                continue

            all_fold_dicts = list(results.values()) if isinstance(results, dict) else list(results)
            metric_names = sorted({k for d in all_fold_dicts for k in d.keys()})
            for m in metric_names:
                vals = [d.get(m, np.nan) for d in all_fold_dicts]
                vals = [float(x) for x in vals if x is not None]
                mean_across_folds = np.nan if len(vals) == 0 else float(np.nanmean(vals))
                records[g][m].append(mean_across_folds)

    # Desired column order
    desired_order = [
        "gap",
        "link_auc_mean",
        "conf_mae_mean",
        "conf_nll_mean",
        "stance_nll_mean",
        "stance_kl_mean"
    ]

    # Build DataFrame with mean across repeats (no std)
    rows = []
    all_metrics = sorted({m for rec in records.values() for m in rec.keys()})
    for g in gaps:
        row = {"gap": g}
        for m in all_metrics:
            arr = np.array(records[g].get(m, []), dtype=float)
            mean_over_repeats = float(np.nan) if arr.size == 0 else float(np.nanmean(arr))
            row[f"{m}_mean"] = mean_over_repeats
        rows.append(row)

    df = pd.DataFrame(rows)

    # Ensure all desired columns exist and reorder
    for col in desired_order:
        if col not in df.columns:
            df[col] = np.nan
    df = df[desired_order]

    # Format to 3 digits
    pd.options.display.float_format = "{:0.3f}".format

    print("\nGap ablation — test metrics (means across folds & repeats):")
    display(df)

    try:
        df.to_csv(save_csv, index=False, float_format="%.3f")
        print(f"Saved summary CSV to: {save_csv}")
    except Exception as e:
        print(f"Could not save CSV: {e}")

    return df, records


# Run and save results
df_means, raw = gap_ablation_test_means(
    gaps=[0,1,2,3], repeats=1, 
    train_args_base=TRAIN_ARGS, model_args=MODEL_ARGS, graph_data=PYG_GRAPHS)
# Out:
# [gap=0] repeat 1/1 seed=42
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: full
#   - Task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#   - Tasks: Link, Confidence, Stance
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,910 nodes | 1,425 edges | Avg: 142.5 edges/graph
#    + Stance Dist: [0.326, 0.225, 0.449] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,328 nodes | 4,308 edges | Avg: 165.7 edges/graph
#    + Stance Dist: [0.406, 0.283, 0.311] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 6,705 nodes | 7,677 edges | Avg: 853.0 edges/graph
#    + Stance Dist: [0.359, 0.214, 0.427] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,022 nodes | 7,296 edges | Avg: 810.7 edges/graph
#    + Stance Dist: [0.402, 0.245, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,251
#   - Total edges: 35,286
#   - Avg nodes/graph: 314.9
#   - Avg edges/graph: 458.3
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.395, 0.261, 0.344] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 53 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.382, 0.240, 0.378] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.078, neutral:-0.201, agree:+0.099
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.602, σ=0.389
#   - Stance dist: [0.223, 0.235, 0.542] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.003, neutral:-0.088, agree:+0.077
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0015)
#   - Stance weights:  [2.617, 4.168, 2.646]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.8437 | Link=18.9204 | Conf=0.0434 | Stance=0.7277
#   - Val:   Total=5.3243 | Link=10.0666 | Conf=0.0509 | Stance=0.5358
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.6710 | Link=0.8761 | Conf=0.0323 | Stance=0.4341
#   - Val:   Total=0.7608 | Link=1.2769 | Conf=0.0402 | Stance=0.2294
#   - Uncertainty: Link=1.001 | Conf=0.987 | Stance=0.985
#   - LR: 1.00e-04
#   Early stopping at epoch 24
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.7700
#    - Conf Mae: 0.3352
#    - Conf Nll: 0.6999
#    - Stance Nll: 0.8439
#    - Stance Kl: 0.8140
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.520, σ=0.375
#   - Stance dist: [0.399, 0.261, 0.340] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.086, neutral:-0.185, agree:+0.082
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0024)
#   - Stance weights:  [2.509, 3.826, 2.940]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.9554 | Link=16.9561 | Conf=0.0422 | Stance=0.7224
#   - Val:   Total=3.9307 | Link=7.2719 | Conf=0.0403 | Stance=0.5530
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7163 | Link=0.9158 | Conf=0.0319 | Stance=0.4837
#   - Val:   Total=0.9324 | Link=1.4355 | Conf=0.0317 | Stance=0.4233
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#   Early stopping at epoch 29
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.9177
#    - Conf Mae: 0.3543
#    - Conf Nll: 0.6926
#    - Stance Nll: 0.3478
#    - Stance Kl: 0.3441
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 50 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.375
#   - Stance dist: [0.394, 0.257, 0.349] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.081, neutral:-0.183, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0023)
#   - Stance weights:  [2.538, 3.896, 2.863]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.0527 | Link=19.0820 | Conf=0.0417 | Stance=0.7137
#   - Val:   Total=5.4724 | Link=10.3587 | Conf=0.0393 | Stance=0.5514
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#   Early stopping at epoch 18
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.8543
#    - Conf Mae: 0.3397
#    - Conf Nll: 0.7982
#    - Stance Nll: 0.8262
#    - Stance Kl: 0.8243
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 67 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.518, σ=0.374
#   - Stance dist: [0.406, 0.273, 0.321] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.087, neutral:-0.176, agree:+0.076
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0030)
#   - Stance weights:  [2.464, 3.665, 3.113]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.5994 | Link=16.1346 | Conf=0.0431 | Stance=0.7247
#   - Val:   Total=3.5660 | Link=6.5433 | Conf=0.0402 | Stance=0.5521
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7269 | Link=0.9450 | Conf=0.0323 | Stance=0.4775
#   - Val:   Total=0.9413 | Link=1.4467 | Conf=0.0315 | Stance=0.4308
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.982
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.9117
#    - Conf Mae: 0.3437
#    - Conf Nll: 0.6981
#    - Stance Nll: 0.5839
#    - Stance Kl: 0.5813
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 67 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.516, σ=0.374
#   - Stance dist: [0.394, 0.264, 0.342] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.089, neutral:-0.187, agree:+0.082
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0034)
#   - Stance weights:  [2.539, 3.790, 2.922]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.2005 | Link=17.3510 | Conf=0.0420 | Stance=0.7249
#   - Val:   Total=4.2508 | Link=7.9134 | Conf=0.0397 | Stance=0.5528
#   - Uncertainty: Link=1.001 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7316 | Link=0.9497 | Conf=0.0326 | Stance=0.4815
#   - Val:   Total=1.0117 | Link=1.5823 | Conf=0.0335 | Stance=0.4349
#   - Uncertainty: Link=1.004 | Conf=0.984 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.9144
#    - Conf Mae: 0.3452
#    - Conf Nll: 0.7099
#    - Stance Nll: 0.5481
#    - Stance Kl: 0.5464
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.7700
#      - Conf Mae          : 0.3352
#      - Conf Nll          : 0.6999
#      - Stance Nll        : 0.8439
#      - Stance Kl         : 0.8140
#   Subreddit 1:
#      - Link Auc          : 0.9177
#      - Conf Mae          : 0.3543
#      - Conf Nll          : 0.6926
#      - Stance Nll        : 0.3478
#      - Stance Kl         : 0.3441
#   Subreddit 2:
#      - Link Auc          : 0.8543
#      - Conf Mae          : 0.3397
#      - Conf Nll          : 0.7982
#      - Stance Nll        : 0.8262
#      - Stance Kl         : 0.8243
#   Subreddit 3:
#      - Link Auc          : 0.9117
#      - Conf Mae          : 0.3437
#      - Conf Nll          : 0.6981
#      - Stance Nll        : 0.5839
#      - Stance Kl         : 0.5813
#   Subreddit 4:
#      - Link Auc          : 0.9144
#      - Conf Mae          : 0.3452
#      - Conf Nll          : 0.7099
#      - Stance Nll        : 0.5481
#      - Stance Kl         : 0.5464
#
# *** Average Test Performance ***
#   - Conf Mae            : 0.3436
#   - Conf Nll            : 0.7197
#   - Link Auc            : 0.8736
#   - Stance Kl           : 0.6220
#   - Stance Nll          : 0.6300
# [gap=1] repeat 1/1 seed=42
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: full
#   - Task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#   - Tasks: Link, Confidence, Stance
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,910 nodes | 1,425 edges | Avg: 142.5 edges/graph
#    + Stance Dist: [0.326, 0.225, 0.449] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,328 nodes | 4,308 edges | Avg: 165.7 edges/graph
#    + Stance Dist: [0.406, 0.283, 0.311] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 6,705 nodes | 7,677 edges | Avg: 853.0 edges/graph
#    + Stance Dist: [0.359, 0.214, 0.427] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,022 nodes | 7,296 edges | Avg: 810.7 edges/graph
#    + Stance Dist: [0.402, 0.245, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,251
#   - Total edges: 35,286
#   - Avg nodes/graph: 314.9
#   - Avg edges/graph: 458.3
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.395, 0.261, 0.344] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 52 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 1 timestep(s) skipped: [8]
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.382, 0.240, 0.378] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.077, neutral:-0.201, agree:+0.100
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.602, σ=0.389
#   - Stance dist: [0.223, 0.235, 0.542] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.003, neutral:-0.088, agree:+0.077
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0015)
#   - Stance weights:  [2.615, 4.167, 2.649]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.8959 | Link=19.0247 | Conf=0.0434 | Stance=0.7278
#   - Val:   Total=5.4117 | Link=10.2363 | Conf=0.0514 | Stance=0.5403
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.6513 | Link=0.8427 | Conf=0.0322 | Stance=0.4266
#   - Val:   Total=0.5340 | Link=0.8439 | Conf=0.0353 | Stance=0.2134
#   - Uncertainty: Link=1.000 | Conf=0.987 | Stance=0.985
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.8359
#    - Conf Mae: 0.3374
#    - Conf Nll: 0.7022
#    - Stance Nll: 0.8389
#    - Stance Kl: 0.8090
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 65 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.399, 0.260, 0.341] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.086, neutral:-0.186, agree:+0.083
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0024)
#   - Stance weights:  [2.505, 3.842, 2.937]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.0096 | Link=17.0612 | Conf=0.0421 | Stance=0.7217
#   - Val:   Total=3.9721 | Link=7.3542 | Conf=0.0406 | Stance=0.5533
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#   Early stopping at epoch 19
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.9022
#    - Conf Mae: 0.3563
#    - Conf Nll: 0.6881
#    - Stance Nll: 0.3644
#    - Stance Kl: 0.3608
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 49 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.520, σ=0.375
#   - Stance dist: [0.395, 0.255, 0.350] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.081, neutral:-0.184, agree:+0.085
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0022)
#   - Stance weights:  [2.533, 3.915, 2.859]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.1104 | Link=19.1969 | Conf=0.0419 | Stance=0.7138
#   - Val:   Total=5.5770 | Link=10.5671 | Conf=0.0392 | Stance=0.5524
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.8284 | Link=1.0451 | Conf=0.0331 | Stance=0.5754
#   - Val:   Total=0.9450 | Link=1.4005 | Conf=0.0306 | Stance=0.4797
#   - Uncertainty: Link=1.004 | Conf=0.987 | Stance=0.986
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.9018
#    - Conf Mae: 0.3449
#    - Conf Nll: 0.7322
#    - Stance Nll: 0.5524
#    - Stance Kl: 0.5504
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.374
#   - Stance dist: [0.407, 0.272, 0.321] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.087, neutral:-0.176, agree:+0.076
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0030)
#   - Stance weights:  [2.457, 3.680, 3.112]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.6588 | Link=16.2542 | Conf=0.0431 | Stance=0.7245
#   - Val:   Total=3.6357 | Link=6.6807 | Conf=0.0406 | Stance=0.5538
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7109 | Link=0.9159 | Conf=0.0319 | Stance=0.4745
#   - Val:   Total=0.9716 | Link=1.5063 | Conf=0.0324 | Stance=0.4307
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.9143
#    - Conf Mae: 0.3461
#    - Conf Nll: 0.6957
#    - Stance Nll: 0.5994
#    - Stance Kl: 0.5969
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.517, σ=0.374
#   - Stance dist: [0.395, 0.263, 0.343] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.088, neutral:-0.187, agree:+0.082
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0034)
#   - Stance weights:  [2.534, 3.808, 2.918]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.2683 | Link=17.4852 | Conf=0.0421 | Stance=0.7255
#   - Val:   Total=4.3484 | Link=8.1076 | Conf=0.0396 | Stance=0.5539
#   - Uncertainty: Link=1.001 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7218 | Link=0.9346 | Conf=0.0324 | Stance=0.4773
#   - Val:   Total=0.9396 | Link=1.4449 | Conf=0.0323 | Stance=0.4284
#   - Uncertainty: Link=1.003 | Conf=0.984 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.9160
#    - Conf Mae: 0.3462
#    - Conf Nll: 0.7145
#    - Stance Nll: 0.5605
#    - Stance Kl: 0.5588
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.8359
#      - Conf Mae          : 0.3374
#      - Conf Nll          : 0.7022
#      - Stance Nll        : 0.8389
#      - Stance Kl         : 0.8090
#   Subreddit 1:
#      - Link Auc          : 0.9022
#      - Conf Mae          : 0.3563
#      - Conf Nll          : 0.6881
#      - Stance Nll        : 0.3644
#      - Stance Kl         : 0.3608
#   Subreddit 2:
#      - Link Auc          : 0.9018
#      - Conf Mae          : 0.3449
#      - Conf Nll          : 0.7322
#      - Stance Nll        : 0.5524
#      - Stance Kl         : 0.5504
#   Subreddit 3:
#      - Link Auc          : 0.9143
#      - Conf Mae          : 0.3461
#      - Conf Nll          : 0.6957
#      - Stance Nll        : 0.5994
#      - Stance Kl         : 0.5969
#   Subreddit 4:
#      - Link Auc          : 0.9160
#      - Conf Mae          : 0.3462
#      - Conf Nll          : 0.7145
#      - Stance Nll        : 0.5605
#      - Stance Kl         : 0.5588
#
# *** Average Test Performance ***
#   - Conf Mae            : 0.3462
#   - Conf Nll            : 0.7065
#   - Link Auc            : 0.8941
#   - Stance Kl           : 0.5752
#   - Stance Nll          : 0.5831
# [gap=2] repeat 1/1 seed=42
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: full
#   - Task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#   - Tasks: Link, Confidence, Stance
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,910 nodes | 1,425 edges | Avg: 142.5 edges/graph
#    + Stance Dist: [0.326, 0.225, 0.449] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,328 nodes | 4,308 edges | Avg: 165.7 edges/graph
#    + Stance Dist: [0.406, 0.283, 0.311] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 6,705 nodes | 7,677 edges | Avg: 853.0 edges/graph
#    + Stance Dist: [0.359, 0.214, 0.427] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,022 nodes | 7,296 edges | Avg: 810.7 edges/graph
#    + Stance Dist: [0.402, 0.245, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,251
#   - Total edges: 35,286
#   - Avg nodes/graph: 314.9
#   - Avg edges/graph: 458.3
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.395, 0.261, 0.344] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 51 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 1 timestep(s) skipped: [7, 8]
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.383, 0.240, 0.377] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.078, neutral:-0.200, agree:+0.098
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.602, σ=0.389
#   - Stance dist: [0.223, 0.235, 0.542] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.003, neutral:-0.088, agree:+0.077
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0015)
#   - Stance weights:  [2.611, 4.169, 2.651]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.9454 | Link=19.1238 | Conf=0.0434 | Stance=0.7277
#   - Val:   Total=5.4970 | Link=10.4043 | Conf=0.0512 | Stance=0.5432
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#   Early stopping at epoch 19
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.7247
#    - Conf Mae: 0.3227
#    - Conf Nll: 0.7007
#    - Stance Nll: 0.8513
#    - Stance Kl: 0.8214
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 64 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 0 timestep(s) skipped: [20, 21]
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.522, σ=0.376
#   - Stance dist: [0.400, 0.258, 0.342] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.087, neutral:-0.189, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0023)
#   - Stance weights:  [2.499, 3.873, 2.927]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.0680 | Link=17.1764 | Conf=0.0423 | Stance=0.7226
#   - Val:   Total=4.0607 | Link=7.5289 | Conf=0.0407 | Stance=0.5557
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#   Early stopping at epoch 19
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.8813
#    - Conf Mae: 0.3544
#    - Conf Nll: 0.7005
#    - Stance Nll: 0.3631
#    - Stance Kl: 0.3594
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 48 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 0 timestep(s) skipped: [20, 21]
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.396, 0.253, 0.352] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.082, neutral:-0.188, agree:+0.087
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0022)
#   - Stance weights:  [2.528, 3.954, 2.845]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.1546 | Link=19.3003 | Conf=0.0420 | Stance=0.7138
#   - Val:   Total=5.6498 | Link=10.7126 | Conf=0.0390 | Stance=0.5526
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.8308 | Link=1.0502 | Conf=0.0331 | Stance=0.5744
#   - Val:   Total=1.0041 | Link=1.5132 | Conf=0.0318 | Stance=0.4840
#   - Uncertainty: Link=1.004 | Conf=0.988 | Stance=0.987
#   - LR: 1.00e-04
#   Early stopping at epoch 20
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.8638
#    - Conf Mae: 0.3442
#    - Conf Nll: 0.7584
#    - Stance Nll: 0.7940
#    - Stance Kl: 0.7921
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 65 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 0 timestep(s) skipped: [20, 21]
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.374
#   - Stance dist: [0.409, 0.270, 0.322] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.088, neutral:-0.180, agree:+0.078
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0029)
#   - Stance weights:  [2.448, 3.706, 3.109]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.7130 | Link=16.3692 | Conf=0.0432 | Stance=0.7239
#   - Val:   Total=3.7019 | Link=6.8125 | Conf=0.0404 | Stance=0.5545
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7290 | Link=0.9501 | Conf=0.0324 | Stance=0.4745
#   - Val:   Total=0.9681 | Link=1.4979 | Conf=0.0318 | Stance=0.4320
#   - Uncertainty: Link=1.002 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.9160
#    - Conf Mae: 0.3466
#    - Conf Nll: 0.7001
#    - Stance Nll: 0.5945
#    - Stance Kl: 0.5920
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 65 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 0 timestep(s) skipped: [20, 21]
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.374
#   - Stance dist: [0.396, 0.260, 0.344] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.090, neutral:-0.192, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0033)
#   - Stance weights:  [2.528, 3.843, 2.905]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.3199 | Link=17.5899 | Conf=0.0421 | Stance=0.7254
#   - Val:   Total=4.4263 | Link=8.2628 | Conf=0.0398 | Stance=0.5544
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7101 | Link=0.9118 | Conf=0.0321 | Stance=0.4758
#   - Val:   Total=0.9412 | Link=1.4458 | Conf=0.0326 | Stance=0.4300
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#   Early stopping at epoch 20
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.8834
#    - Conf Mae: 0.3502
#    - Conf Nll: 0.7282
#    - Stance Nll: 0.5885
#    - Stance Kl: 0.5868
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.7247
#      - Conf Mae          : 0.3227
#      - Conf Nll          : 0.7007
#      - Stance Nll        : 0.8513
#      - Stance Kl         : 0.8214
#   Subreddit 1:
#      - Link Auc          : 0.8813
#      - Conf Mae          : 0.3544
#      - Conf Nll          : 0.7005
#      - Stance Nll        : 0.3631
#      - Stance Kl         : 0.3594
#   Subreddit 2:
#      - Link Auc          : 0.8638
#      - Conf Mae          : 0.3442
#      - Conf Nll          : 0.7584
#      - Stance Nll        : 0.7940
#      - Stance Kl         : 0.7921
#   Subreddit 3:
#      - Link Auc          : 0.9160
#      - Conf Mae          : 0.3466
#      - Conf Nll          : 0.7001
#      - Stance Nll        : 0.5945
#      - Stance Kl         : 0.5920
#   Subreddit 4:
#      - Link Auc          : 0.8834
#      - Conf Mae          : 0.3502
#      - Conf Nll          : 0.7282
#      - Stance Nll        : 0.5885
#      - Stance Kl         : 0.5868
#
# *** Average Test Performance ***
#   - Conf Mae            : 0.3436
#   - Conf Nll            : 0.7176
#   - Link Auc            : 0.8538
#   - Stance Kl           : 0.6304
#   - Stance Nll          : 0.6383
# [gap=3] repeat 1/1 seed=42
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: full
#   - Task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#   - Tasks: Link, Confidence, Stance
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,910 nodes | 1,425 edges | Avg: 142.5 edges/graph
#    + Stance Dist: [0.326, 0.225, 0.449] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,328 nodes | 4,308 edges | Avg: 165.7 edges/graph
#    + Stance Dist: [0.406, 0.283, 0.311] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 6,705 nodes | 7,677 edges | Avg: 853.0 edges/graph
#    + Stance Dist: [0.359, 0.214, 0.427] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,022 nodes | 7,296 edges | Avg: 810.7 edges/graph
#    + Stance Dist: [0.402, 0.245, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,251
#   - Total edges: 35,286
#   - Avg nodes/graph: 314.9
#   - Avg edges/graph: 458.3
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.395, 0.261, 0.344] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 50 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 1 timestep(s) skipped: [6, 7, 8]
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.383, 0.240, 0.377] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.078, neutral:-0.200, agree:+0.098
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.602, σ=0.389
#   - Stance dist: [0.223, 0.235, 0.542] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.003, neutral:-0.088, agree:+0.077
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0015)
#   - Stance weights:  [2.609, 4.170, 2.653]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.9955 | Link=19.2239 | Conf=0.0434 | Stance=0.7277
#   - Val:   Total=5.5822 | Link=10.5731 | Conf=0.0513 | Stance=0.5446
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#   Early stopping at epoch 19
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.7379
#    - Conf Mae: 0.3206
#    - Conf Nll: 0.7043
#    - Stance Nll: 0.8720
#    - Stance Kl: 0.8421
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 63 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 0 timestep(s) skipped: [19, 20, 21]
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.523, σ=0.376
#   - Stance dist: [0.401, 0.257, 0.342] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.087, neutral:-0.190, agree:+0.086
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0022)
#   - Stance weights:  [2.493, 3.889, 2.926]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.1239 | Link=17.2846 | Conf=0.0423 | Stance=0.7224
#   - Val:   Total=4.1311 | Link=7.6699 | Conf=0.0409 | Stance=0.5554
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7288 | Link=0.9418 | Conf=0.0324 | Stance=0.4806
#   - Val:   Total=0.9348 | Link=1.4397 | Conf=0.0310 | Stance=0.4235
#   - Uncertainty: Link=1.002 | Conf=0.985 | Stance=0.984
#   - LR: 1.00e-04
#   Early stopping at epoch 20
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.8977
#    - Conf Mae: 0.3558
#    - Conf Nll: 0.6907
#    - Stance Nll: 0.3595
#    - Stance Kl: 0.3558
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 47 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 0 timestep(s) skipped: [19, 20, 21]
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.522, σ=0.376
#   - Stance dist: [0.396, 0.251, 0.352] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.081, neutral:-0.189, agree:+0.088
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0021)
#   - Stance weights:  [2.522, 3.976, 2.841]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.1979 | Link=19.3852 | Conf=0.0420 | Stance=0.7138
#   - Val:   Total=5.7153 | Link=10.8422 | Conf=0.0393 | Stance=0.5536
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.8412 | Link=1.0764 | Conf=0.0334 | Stance=0.5672
#   - Val:   Total=1.0344 | Link=1.5801 | Conf=0.0323 | Stance=0.4772
#   - Uncertainty: Link=1.004 | Conf=0.988 | Stance=0.987
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.8857
#    - Conf Mae: 0.3408
#    - Conf Nll: 0.7418
#    - Stance Nll: 0.5729
#    - Stance Kl: 0.5710
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 64 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 0 timestep(s) skipped: [19, 20, 21]
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.522, σ=0.375
#   - Stance dist: [0.410, 0.269, 0.321] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.088, neutral:-0.181, agree:+0.080
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0028)
#   - Stance weights:  [2.439, 3.720, 3.114]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.7661 | Link=16.4759 | Conf=0.0433 | Stance=0.7245
#   - Val:   Total=3.7743 | Link=6.9559 | Conf=0.0407 | Stance=0.5556
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7179 | Link=0.9321 | Conf=0.0319 | Stance=0.4712
#   - Val:   Total=0.9874 | Link=1.5358 | Conf=0.0324 | Stance=0.4322
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#   Early stopping at epoch 21
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.8968
#    - Conf Mae: 0.3426
#    - Conf Nll: 0.7179
#    - Stance Nll: 0.6062
#    - Stance Kl: 0.6037
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 64 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 0 timestep(s) skipped: [19, 20, 21]
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.375
#   - Stance dist: [0.397, 0.259, 0.345] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.089, neutral:-0.193, agree:+0.086
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0032)
#   - Stance weights:  [2.522, 3.862, 2.902]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.3649 | Link=17.6742 | Conf=0.0422 | Stance=0.7255
#   - Val:   Total=4.4761 | Link=8.3608 | Conf=0.0401 | Stance=0.5556
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7344 | Link=0.9620 | Conf=0.0328 | Stance=0.4728
#   - Val:   Total=0.9982 | Link=1.5554 | Conf=0.0329 | Stance=0.4340
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#   Early stopping at epoch 22
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.8910
#    - Conf Mae: 0.3504
#    - Conf Nll: 0.7216
#    - Stance Nll: 0.5782
#    - Stance Kl: 0.5765
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.7379
#      - Conf Mae          : 0.3206
#      - Conf Nll          : 0.7043
#      - Stance Nll        : 0.8720
#      - Stance Kl         : 0.8421
#   Subreddit 1:
#      - Link Auc          : 0.8977
#      - Conf Mae          : 0.3558
#      - Conf Nll          : 0.6907
#      - Stance Nll        : 0.3595
#      - Stance Kl         : 0.3558
#   Subreddit 2:
#      - Link Auc          : 0.8857
#      - Conf Mae          : 0.3408
#      - Conf Nll          : 0.7418
#      - Stance Nll        : 0.5729
#      - Stance Kl         : 0.5710
#   Subreddit 3:
#      - Link Auc          : 0.8968
#      - Conf Mae          : 0.3426
#      - Conf Nll          : 0.7179
#      - Stance Nll        : 0.6062
#      - Stance Kl         : 0.6037
#   Subreddit 4:
#      - Link Auc          : 0.8910
#      - Conf Mae          : 0.3504
#      - Conf Nll          : 0.7216
#      - Stance Nll        : 0.5782
#      - Stance Kl         : 0.5765
#
# *** Average Test Performance ***
#   - Conf Mae            : 0.3420
#   - Conf Nll            : 0.7153
#   - Link Auc            : 0.8618
#   - Stance Kl           : 0.5898
#   - Stance Nll          : 0.5978
# Gap ablation — test metrics (means across folds & repeats):
#    gap  link_auc_mean  conf_mae_mean  conf_nll_mean  stance_nll_mean  \
# 0    0          0.874          0.344          0.720            0.630
# 1    1          0.894          0.346          0.707            0.583
# 2    2          0.854          0.344          0.718            0.638
# 3    3          0.862          0.342          0.715            0.598
#
#    stance_kl_mean
# 0           0.622
# 1           0.575
# 2           0.630
# 3           0.590
# Saved summary CSV to: results/gap_ablation_test_means.csv
