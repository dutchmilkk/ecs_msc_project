# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")   # type: ignore

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PYG_GRAPHS = torch.load("data/processed/pyg_graphs_384D.pt", weights_only=False)
# Out:
# PyTorch version: 2.8.0+cu128
# CUDA available: True
# CUDA version: 12.8

# %%
## HELPER FUNCTIONS FOR CREATING AND TRAINING MODEL
import importlib
import src.models.multitask_debate_gnn
importlib.reload(src.models.multitask_debate_gnn)

from src.models.multitask_debate_gnn import ECCConv, MultitaskDebateGNN, train_gnn_live, plot_cv_losses
from torch_geometric.nn import GCNConv, SAGEConv

from typing import Dict, Any, Type, Optional

def create_and_describe_model(model_args: Dict[str, Any], model_class: Type[MultitaskDebateGNN] = MultitaskDebateGNN) -> Optional[MultitaskDebateGNN]:
    """Build the model from args, print a summary, and return the instance (or None on failure)."""
    try:
        model = model_class(**model_args)
        print("Model created:")
        print(f"   Architecture: {[type(conv).__name__ for conv in model.convs]}")
        print(f"   Mode: {model.mode}")
        print(f"   Input dim: {model_args['in_dim']}")
        print(f"   Hidden dim: {model_args['hidden_dim']}")
        print(f"   Embedding dim: {model_args['emb_dim']}")
        print(f"   Number of layers: {model_args['num_layers']}")

        # Count parameters
        total_params = sum(p.numel() for p in model.parameters())
        trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
        print("\nModel Statistics:")
        print(f"   Total parameters: {total_params:,}")
        print(f"   Trainable parameters: {trainable_params:,}")
        print(f"   Model size: ~{total_params * 4 / 1024**2:.1f} MB")

        # Show model structure
        print("\nModel Structure:")
        print(model)
        return model

    except Exception as e:
        print(f"Error creating model: {e}")
        import traceback
        traceback.print_exc()
        return None
    
def run_cv_training(
    graph_data,
    model_args: dict,
    train_args: dict,
    model_class: Type[MultitaskDebateGNN] = MultitaskDebateGNN,
    live_plot: bool = False,):
    """
    Runs cross-validation training with cleanup and plotting.
    Returns (model, results, cv_history) or (None, None, None) on failure.
    """
    import gc, traceback
    import torch

    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    try:
        model, results, cv_history = train_gnn_live(
            all_graphs=getattr(graph_data, "pyg_graphs", graph_data),
            model_args=model_args,
            train_args=train_args,
            model_class=model_class,
            live_plot=live_plot,
        )
        plot_cv_losses(cv_history=cv_history)
        return model, results, cv_history
    except Exception as e:
        print(f"Training error: {e}")
        traceback.print_exc()
        return None, None, None

# %%
# BASE MODEL AND TRAINING ARGS (shared across all variants)
BASE_MODEL_ARGS = dict(
    in_dim = 384,
    hidden_dim = 256,
    emb_dim = 128,
    neg_attr_weight = 0.3,
    dropout = 0.15,
)

ECC_KWARGS = dict(
    edge_mlp_dropout = 0.1,
    keep_prob = 0.8,
    conf_dim = 1,
    stance_dim = 3
)

BASE_TRAIN_ARGS = dict(
    epochs = 30,
    lr = 0.001,
    patience = 6,
    min_delta = 3e-4,
    neg_sample_ratio = 0.5,
    temp_reg_weight = 0.1,
    val_n_last = 1, # or val_pct_last = 0.25 (pick either one)
    val_gap_n = 1,
)

# To store cv results later
TRAIN_RESULTS = {
    "3-GCN": None,
    "3-SAGE": None,
    "2-SAGE-1-ECC": None,
}
TRAINED_MODELS = {
    "3-GCN": None,
    "3-SAGE": None,
    "2-SAGE-1-ECC": None,
}

# %%
# DEFINE VARIANTS ARGS

# 1. 3-GCN -> Link Only
# Take base args for link only
_3gcn_margs = BASE_MODEL_ARGS | dict(
    num_layers=3,
    mode="link_only",
    conv_cls=GCNConv
)

# 2. 3-SAGE -> Link Only
# Take base args for linky only
_3sage_margs = BASE_MODEL_ARGS | dict(
    num_layers=3,
    mode="link_only",
    conv_cls=SAGEConv
)

# 3. 2-SAGE-1-ECC -> Full
_2sage_1ecc_F_margs = BASE_MODEL_ARGS | dict(
    num_layers=3,
    mode="full",
    conv_cls_list=[SAGEConv, SAGEConv, ECCConv],
    ecc_kwargs=ECC_KWARGS   # Share ECC args for all with ECC layer
)

# %% [markdown]
# ### **3-GCN** (Link Only)

# %%
print("Training 3-GCN...")

_3gcn_model, _3gcn_results, _3gcn_cv_history = run_cv_training(
    graph_data = PYG_GRAPHS,
    model_args = _3gcn_margs,
    train_args = BASE_TRAIN_ARGS,
    model_class = MultitaskDebateGNN,
    live_plot = False
)
# Save trained model and result to dict
TRAIN_RESULTS['3-GCN'] = _3gcn_results
TRAINED_MODELS['3-GCN'] = _3gcn_model
# Out:
# Training 3-GCN...
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: link_only
#   - Task weights: Default (1.0 each)
#   - Tasks: Link
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,084 nodes | 938 edges | Avg: 93.8 edges/graph
#    + Stance Dist: [0.322, 0.239, 0.439] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,291 nodes | 4,297 edges | Avg: 165.3 edges/graph
#    + Stance Dist: [0.407, 0.283, 0.310] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 7,302 nodes | 8,143 edges | Avg: 904.8 edges/graph
#    + Stance Dist: [0.360, 0.216, 0.424] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,417 nodes | 7,598 edges | Avg: 844.2 edges/graph
#    + Stance Dist: [0.401, 0.246, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,380
#   - Total edges: 35,556
#   - Avg nodes/graph: 316.6
#   - Avg edges/graph: 461.8
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.396, 0.262, 0.343] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 52 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 1 timestep(s) skipped: [8]
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.383, 0.242, 0.375] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.078, neutral:-0.200, agree:+0.099
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.574, σ=0.387
#   - Stance dist: [0.221, 0.270, 0.508] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.008, neutral:-0.035, agree:+0.037
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0014)
#   - Stance weights:  [2.609, 4.140, 2.666]
#
# Model Configs:
#   - Total parameters: 280,834 (trainable: 280,834)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.1867 | Link=18.3770 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=4.7178 | Link=9.4392 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.000 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#   Early stopping at epoch 10
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.6423
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 65 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.376
#   - Stance dist: [0.399, 0.260, 0.341] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.085, neutral:-0.185, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0021)
#   - Stance weights:  [2.507, 3.842, 2.934]
#
# Model Configs:
#   - Total parameters: 280,834 (trainable: 280,834)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.0187 | Link=17.9177 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=4.2203 | Link=8.4444 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.001 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#   Early stopping at epoch 17
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.7178
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 49 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.520, σ=0.375
#   - Stance dist: [0.395, 0.256, 0.348] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.081, neutral:-0.183, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0020)
#   - Stance weights:  [2.529, 3.900, 2.872]
#
# Model Configs:
#   - Total parameters: 280,834 (trainable: 280,834)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.7275 | Link=19.2859 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=5.3150 | Link=10.6339 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.000 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#   Early stopping at epoch 19
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.7065
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.374
#   - Stance dist: [0.408, 0.273, 0.319] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.088, neutral:-0.176, agree:+0.075
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0028)
#   - Stance weights:  [2.450, 3.662, 3.138]
#
# Model Configs:
#   - Total parameters: 280,834 (trainable: 280,834)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.9355 | Link=17.6920 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=3.9324 | Link=7.8684 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.001 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7526 | Link=1.4757 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=1.0273 | Link=2.0663 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.011 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#   Early stopping at epoch 20
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.7767
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.517, σ=0.374
#   - Stance dist: [0.396, 0.264, 0.341] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.089, neutral:-0.186, agree:+0.081
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0031)
#   - Stance weights:  [2.528, 3.792, 2.935]
#
# Model Configs:
#   - Total parameters: 280,834 (trainable: 280,834)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.5414 | Link=16.9216 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=3.6743 | Link=7.3517 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.000 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7793 | Link=1.5318 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=1.0183 | Link=2.0487 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.012 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.8346
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.6423
#   Subreddit 1:
#      - Link Auc          : 0.7178
#   Subreddit 2:
#      - Link Auc          : 0.7065
#   Subreddit 3:
#      - Link Auc          : 0.7767
#   Subreddit 4:
#      - Link Auc          : 0.8346
#
# *** Average Test Performance ***
#   - Link Auc            : 0.7356

# %% [markdown]
# ### **3-SAGE** (Link Only)

# %%
print("Training 3-SAGE...")
_3sage_model, _3sage_results, _3sage_cv_history = run_cv_training(
    graph_data = PYG_GRAPHS,
    model_args = _3sage_margs,
    train_args = BASE_TRAIN_ARGS,
    model_class = MultitaskDebateGNN,
    live_plot = False
)
# Save trained model and result to dict
TRAIN_RESULTS['3-SAGE'] = _3sage_results
TRAINED_MODELS['3-SAGE'] = _3sage_model
# Out:
# Training 3-SAGE...
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: link_only
#   - Task weights: Default (1.0 each)
#   - Tasks: Link
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,084 nodes | 938 edges | Avg: 93.8 edges/graph
#    + Stance Dist: [0.322, 0.239, 0.439] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,291 nodes | 4,297 edges | Avg: 165.3 edges/graph
#    + Stance Dist: [0.407, 0.283, 0.310] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 7,302 nodes | 8,143 edges | Avg: 904.8 edges/graph
#    + Stance Dist: [0.360, 0.216, 0.424] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,417 nodes | 7,598 edges | Avg: 844.2 edges/graph
#    + Stance Dist: [0.401, 0.246, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,380
#   - Total edges: 35,556
#   - Avg nodes/graph: 316.6
#   - Avg edges/graph: 461.8
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.396, 0.262, 0.343] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 52 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 1 timestep(s) skipped: [8]
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.383, 0.242, 0.375] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.078, neutral:-0.200, agree:+0.099
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.574, σ=0.387
#   - Stance dist: [0.221, 0.270, 0.508] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.008, neutral:-0.035, agree:+0.037
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0014)
#   - Stance weights:  [2.609, 4.140, 2.666]
#
# Model Configs:
#   - Total parameters: 477,442 (trainable: 477,442)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.5215 | Link=19.0468 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=5.1426 | Link=10.2892 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.000 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.4077 | Link=0.8090 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=0.3633 | Link=0.7271 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=0.998 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#   Early stopping at epoch 23
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.7579
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 65 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.376
#   - Stance dist: [0.399, 0.260, 0.341] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.085, neutral:-0.185, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0021)
#   - Stance weights:  [2.507, 3.842, 2.934]
#
# Model Configs:
#   - Total parameters: 477,442 (trainable: 477,442)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.7269 | Link=17.3146 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=3.8828 | Link=7.7688 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.000 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.4550 | Link=0.9002 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=0.6932 | Link=1.3870 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.001 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.8944
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 49 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.520, σ=0.375
#   - Stance dist: [0.395, 0.256, 0.348] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.081, neutral:-0.183, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0020)
#   - Stance weights:  [2.529, 3.900, 2.872]
#
# Model Configs:
#   - Total parameters: 477,442 (trainable: 477,442)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.6756 | Link=19.1640 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=5.3260 | Link=10.6560 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.000 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.5003 | Link=0.9895 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=0.6497 | Link=1.3003 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.003 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.9190
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.374
#   - Stance dist: [0.408, 0.273, 0.319] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.088, neutral:-0.176, agree:+0.075
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0028)
#   - Stance weights:  [2.450, 3.662, 3.138]
#
# Model Configs:
#   - Total parameters: 477,442 (trainable: 477,442)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.6690 | Link=17.1184 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=3.7508 | Link=7.5049 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.000 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.4415 | Link=0.8729 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=0.7098 | Link=1.4199 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.001 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.9199
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.517, σ=0.374
#   - Stance dist: [0.396, 0.264, 0.341] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.089, neutral:-0.186, agree:+0.081
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0031)
#   - Stance weights:  [2.528, 3.792, 2.935]
#
# Model Configs:
#   - Total parameters: 477,442 (trainable: 477,442)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Task weights: Default (uncertainty-only)
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.9922 | Link=17.7828 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=4.2849 | Link=8.5737 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.001 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.4324 | Link=0.8547 | Conf=0.0000 | Stance=0.0000
#   - Val:   Total=0.6508 | Link=1.3017 | Conf=0.0000 | Stance=0.0000
#   - Uncertainty: Link=1.001 | Conf=N/A | Stance=N/A
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.9167
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.7579
#   Subreddit 1:
#      - Link Auc          : 0.8944
#   Subreddit 2:
#      - Link Auc          : 0.9190
#   Subreddit 3:
#      - Link Auc          : 0.9199
#   Subreddit 4:
#      - Link Auc          : 0.9167
#
# *** Average Test Performance ***
#   - Link Auc            : 0.8816

# %% [markdown]
# ### **2-SAGE-1-ECC** (Full)

# %%
print("Training 2-SAGE-1-ECC (Full)...")
_2sage_1ecc_F_model, _2sage_1ecc_F_results, _2sage_1ecc_F_cv_history = run_cv_training(
    graph_data = PYG_GRAPHS,
    model_args = _2sage_1ecc_F_margs,
    train_args = BASE_TRAIN_ARGS | dict(
        task_weights = {"link": 1.0, "conf": 1.0, "stance": 1.0}
    ),
    model_class = MultitaskDebateGNN,
    live_plot = False
)
# Save trained model and result to dict
TRAIN_RESULTS['2-SAGE-1-ECC'] = _2sage_1ecc_F_results
TRAINED_MODELS['2-SAGE-1-ECC'] = _2sage_1ecc_F_model
# Out:
# Training 2-SAGE-1-ECC (Full)...
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: full
#   - Task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#   - Tasks: Link, Confidence, Stance
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,084 nodes | 938 edges | Avg: 93.8 edges/graph
#    + Stance Dist: [0.322, 0.239, 0.439] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,291 nodes | 4,297 edges | Avg: 165.3 edges/graph
#    + Stance Dist: [0.407, 0.283, 0.310] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 7,302 nodes | 8,143 edges | Avg: 904.8 edges/graph
#    + Stance Dist: [0.360, 0.216, 0.424] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,417 nodes | 7,598 edges | Avg: 844.2 edges/graph
#    + Stance Dist: [0.401, 0.246, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,380
#   - Total edges: 35,556
#   - Avg nodes/graph: 316.6
#   - Avg edges/graph: 461.8
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.396, 0.262, 0.343] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 52 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 1 timestep(s) skipped: [8]
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.383, 0.242, 0.375] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.078, neutral:-0.200, agree:+0.099
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.574, σ=0.387
#   - Stance dist: [0.221, 0.270, 0.508] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.008, neutral:-0.035, agree:+0.037
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0014)
#   - Stance weights:  [2.609, 4.140, 2.666]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.0433 | Link=19.3191 | Conf=0.0430 | Stance=0.7288
#   - Val:   Total=5.7108 | Link=10.8311 | Conf=0.0524 | Stance=0.5429
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.6565 | Link=0.8565 | Conf=0.0323 | Stance=0.4210
#   - Val:   Total=0.5456 | Link=0.8708 | Conf=0.0354 | Stance=0.2094
#   - Uncertainty: Link=1.001 | Conf=0.987 | Stance=0.985
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.8308
#    - Conf Mae: 0.3389
#    - Conf Nll: 0.7031
#    - Stance Nll: 0.8437
#    - Stance Kl: 0.8138
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 65 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.376
#   - Stance dist: [0.399, 0.260, 0.341] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.085, neutral:-0.185, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0021)
#   - Stance weights:  [2.507, 3.842, 2.934]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.1773 | Link=17.3912 | Conf=0.0420 | Stance=0.7210
#   - Val:   Total=4.3145 | Link=8.0416 | Conf=0.0397 | Stance=0.5522
#   - Uncertainty: Link=1.001 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#   Early stopping at epoch 18
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.8858
#    - Conf Mae: 0.3479
#    - Conf Nll: 0.7008
#    - Stance Nll: 0.3844
#    - Stance Kl: 0.3807
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 49 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.520, σ=0.375
#   - Stance dist: [0.395, 0.256, 0.348] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.081, neutral:-0.183, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0020)
#   - Stance weights:  [2.529, 3.900, 2.872]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.4695 | Link=19.9006 | Conf=0.0420 | Stance=0.7145
#   - Val:   Total=6.1056 | Link=11.6243 | Conf=0.0401 | Stance=0.5519
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.8289 | Link=1.0380 | Conf=0.0329 | Stance=0.5847
#   - Val:   Total=0.9277 | Link=1.3580 | Conf=0.0306 | Stance=0.4879
#   - Uncertainty: Link=1.004 | Conf=0.987 | Stance=0.986
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.9012
#    - Conf Mae: 0.3424
#    - Conf Nll: 0.7310
#    - Stance Nll: 0.5892
#    - Stance Kl: 0.5873
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.374
#   - Stance dist: [0.408, 0.273, 0.319] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.088, neutral:-0.176, agree:+0.075
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0028)
#   - Stance weights:  [2.450, 3.662, 3.138]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.4636 | Link=17.8876 | Conf=0.0422 | Stance=0.7222
#   - Val:   Total=4.5150 | Link=8.4424 | Conf=0.0402 | Stance=0.5518
#   - Uncertainty: Link=1.001 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7188 | Link=0.9340 | Conf=0.0325 | Stance=0.4705
#   - Val:   Total=0.9658 | Link=1.5033 | Conf=0.0315 | Stance=0.4236
#   - Uncertainty: Link=1.003 | Conf=0.984 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.9163
#    - Conf Mae: 0.3486
#    - Conf Nll: 0.7006
#    - Stance Nll: 0.5936
#    - Stance Kl: 0.5911
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.517, σ=0.374
#   - Stance dist: [0.396, 0.264, 0.341] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.089, neutral:-0.186, agree:+0.081
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0031)
#   - Stance weights:  [2.528, 3.792, 2.935]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.5183 | Link=17.9968 | Conf=0.0419 | Stance=0.7257
#   - Val:   Total=4.6251 | Link=8.6639 | Conf=0.0401 | Stance=0.5510
#   - Uncertainty: Link=1.001 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7073 | Link=0.9076 | Conf=0.0320 | Stance=0.4795
#   - Val:   Total=0.9208 | Link=1.4034 | Conf=0.0315 | Stance=0.4332
#   - Uncertainty: Link=1.002 | Conf=0.984 | Stance=0.982
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.9040
#    - Conf Mae: 0.3522
#    - Conf Nll: 0.7062
#    - Stance Nll: 0.5790
#    - Stance Kl: 0.5774
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.8308
#      - Conf Mae          : 0.3389
#      - Conf Nll          : 0.7031
#      - Stance Nll        : 0.8437
#      - Stance Kl         : 0.8138
#   Subreddit 1:
#      - Link Auc          : 0.8858
#      - Conf Mae          : 0.3479
#      - Conf Nll          : 0.7008
#      - Stance Nll        : 0.3844
#      - Stance Kl         : 0.3807
#   Subreddit 2:
#      - Link Auc          : 0.9012
#      - Conf Mae          : 0.3424
#      - Conf Nll          : 0.7310
#      - Stance Nll        : 0.5892
#      - Stance Kl         : 0.5873
#   Subreddit 3:
#      - Link Auc          : 0.9163
#      - Conf Mae          : 0.3486
#      - Conf Nll          : 0.7006
#      - Stance Nll        : 0.5936
#      - Stance Kl         : 0.5911
#   Subreddit 4:
#      - Link Auc          : 0.9040
#      - Conf Mae          : 0.3522
#      - Conf Nll          : 0.7062
#      - Stance Nll        : 0.5790
#      - Stance Kl         : 0.5774
#
# *** Average Test Performance ***
#   - Conf Mae            : 0.3460
#   - Conf Nll            : 0.7083
#   - Link Auc            : 0.8876
#   - Stance Kl           : 0.5901
#   - Stance Nll          : 0.5980

# %% [markdown]
# ### **FINAL RESULTS**

# %%
import pandas as pd

records = []
for variant, fold_dict in TRAIN_RESULTS.items():
    for fold_id, metrics in fold_dict.items():
        rec = {"variant": variant, "fold": fold_id}
        rec.update(metrics)
        records.append(rec)

df = pd.DataFrame.from_records(records)
wide = (df.pivot(index="fold", columns="variant").sort_index())
wide.loc["MEAN"] = wide.mean()
wide = wide.round(3)
wide
# Out:
#             link_auc                   conf_mae                  conf_nll  \
# variant 2-SAGE-1-ECC  3-GCN 3-SAGE 2-SAGE-1-ECC 3-GCN 3-SAGE 2-SAGE-1-ECC
# fold
# 0              0.831  0.642  0.758        0.339   NaN    NaN        0.703
# 1              0.886  0.718  0.894        0.348   NaN    NaN        0.701
# 2              0.901  0.706  0.919        0.342   NaN    NaN        0.731
# 3              0.916  0.777  0.920        0.349   NaN    NaN        0.701
# 4              0.904  0.835  0.917        0.352   NaN    NaN        0.706
# MEAN           0.888  0.736  0.882        0.346   NaN    NaN        0.708
#
#                        stance_nll                 stance_kl
# variant 3-GCN 3-SAGE 2-SAGE-1-ECC 3-GCN 3-SAGE 2-SAGE-1-ECC 3-GCN 3-SAGE
# fold
# 0         NaN    NaN        0.844   NaN    NaN        0.814   NaN    NaN
# 1         NaN    NaN        0.384   NaN    NaN        0.381   NaN    NaN
# 2         NaN    NaN        0.589   NaN    NaN        0.587   NaN    NaN
# 3         NaN    NaN        0.594   NaN    NaN        0.591   NaN    NaN
# 4         NaN    NaN        0.579   NaN    NaN        0.577   NaN    NaN
# MEAN      NaN    NaN        0.598   NaN    NaN        0.590   NaN    NaN

# %%
df_mean = df.drop(columns="fold").groupby("variant").mean(numeric_only=True).round(3)
df_mean
# Out:
#               link_auc  conf_mae  conf_nll  stance_nll  stance_kl
# variant
# 2-SAGE-1-ECC     0.888     0.346     0.708       0.598       0.59
# 3-GCN            0.736       NaN       NaN         NaN        NaN
# 3-SAGE           0.882       NaN       NaN         NaN        NaN

# %%
import matplotlib.pyplot as plt
import os

os.makedirs("results", exist_ok=True)

plt.figure(figsize=(7,5))
colors = plt.cm.tab10.colors
bars = plt.bar(df_mean.index, df_mean["link_auc"], 
               color=[colors[i % len(colors)] for i in range(len(df_mean))])

plt.bar(df_mean.index, df_mean["link_auc"], 
        color=[colors[i % len(colors)] for i in range(len(df_mean))])

plt.ylabel("Link AUC", fontsize=10)
plt.title("Model Variant Comparison (Link AUC)", fontweight='bold')
plt.xticks()
plt.ylim(0, 1)
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, 
             height + 0.01,
             f"{height:.3f}",
             ha="center", va="bottom", fontsize=12)

plt.tight_layout()
plt.savefig("results/ablation_baseline.png", dpi=300, bbox_inches="tight")
print("Saved result to 'results/ablation_baseline.png'")
plt.show()
# Out:
# Saved result to 'results/ablation_baseline.png'

# %%
df_link = df_mean[["link_auc"]].T.reset_index()
df_link = df_link.rename(columns={"index": "metrics"})
df_link
# Out:
# variant   metrics  2-SAGE-1-ECC  3-GCN  3-SAGE
# 0        link_auc         0.888  0.736   0.882

# %%
print("Saved summary to 'results/ablation/benchmark_link_auc.csv'")
df_link.to_csv("results/ablation/benchmark_link_auc.csv")
# Out:
# Saved summary to 'results/ablation_baseline.csv'
