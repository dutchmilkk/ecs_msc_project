# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")   # type: ignore

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PYG_GRAPHS = torch.load("data/processed/pyg_graphs_384D.pt", weights_only=False)
# Out:
# PyTorch version: 2.5.1
# CUDA available: True
# CUDA version: 12.4

# %%
## HELPER FUNCTIONS FOR CREATING AND TRAINING MODEL
import importlib
import src.models.multitask_debate_gnn
importlib.reload(src.models.multitask_debate_gnn)

from src.models.multitask_debate_gnn import ECCConv, MultitaskDebateGNN, train_gnn_live, plot_cv_losses
from torch_geometric.nn import GCNConv, SAGEConv

from typing import Dict, Any, Type, Optional

def create_and_describe_model(model_args: Dict[str, Any], model_class: Type[MultitaskDebateGNN] = MultitaskDebateGNN) -> Optional[MultitaskDebateGNN]:
    """Build the model from args, print a summary, and return the instance (or None on failure)."""
    try:
        model = model_class(**model_args)
        print("Model created:")
        print(f"   Architecture: {[type(conv).__name__ for conv in model.convs]}")
        print(f"   Mode: {model.mode}")
        print(f"   Input dim: {model_args['in_dim']}")
        print(f"   Hidden dim: {model_args['hidden_dim']}")
        print(f"   Embedding dim: {model_args['emb_dim']}")
        print(f"   Number of layers: {model_args['num_layers']}")

        # Count parameters
        total_params = sum(p.numel() for p in model.parameters())
        trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
        print("\nModel Statistics:")
        print(f"   Total parameters: {total_params:,}")
        print(f"   Trainable parameters: {trainable_params:,}")
        print(f"   Model size: ~{total_params * 4 / 1024**2:.1f} MB")

        # Show model structure
        print("\nModel Structure:")
        print(model)
        return model

    except Exception as e:
        print(f"Error creating model: {e}")
        import traceback
        traceback.print_exc()
        return None
    
def run_cv_training(
    graph_data,
    model_args: dict,
    train_args: dict,
    model_class: Type[MultitaskDebateGNN] = MultitaskDebateGNN,
    live_plot: bool = False,):
    """
    Runs cross-validation training with cleanup and plotting.
    Returns (model, results, cv_history) or (None, None, None) on failure.
    """
    import gc, traceback
    import torch

    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    try:
        model, results, cv_history = train_gnn_live(
            all_graphs=getattr(graph_data, "pyg_graphs", graph_data),
            model_args=model_args,
            train_args=train_args,
            model_class=model_class,
            live_plot=live_plot,
        )
        plot_cv_losses(cv_history=cv_history)
        return model, results, cv_history
    except Exception as e:
        print(f"Training error: {e}")
        traceback.print_exc()
        return None, None, None

# %%
MODEL_ARGS = dict(
    in_dim = 384,
    hidden_dim = 256,
    emb_dim = 128,
    neg_attr_weight = 0.3,
    dropout = 0.15,
    num_layers=3,
    mode="full",
    conv_cls_list=[SAGEConv, SAGEConv, ECCConv],
    ecc_kwargs=dict(
        edge_mlp_dropout=0.1,
        keep_prob=0.8,
        conf_dim=1,
        stance_dim=3
    )
)

TRAIN_ARGS = dict(
    epochs = 30,
    lr = 0.001,
    patience = 6,
    min_delta = 3e-4,
    neg_sample_ratio = 0.5,
    temp_reg_weight = 0.1,
    val_n_last = 1, # or val_pct_last = k (pick either one)
    # val_pct_last = 0.1,
    # val_gap_n = 1,
    task_weights = {"link": 1.0, "conf": 1.0, "stance": 1.0}
)

# See created model
_ = create_and_describe_model(MODEL_ARGS)
# Out:
# Model created:
#    Architecture: ['SAGEConv', 'SAGEConv', 'ECCConv']
#    Mode: full
#    Input dim: 384
#    Hidden dim: 256
#    Embedding dim: 128
#    Number of layers: 3
#
# Model Statistics:
#    Total parameters: 4,741,704
#    Trainable parameters: 4,741,704
#    Model size: ~18.1 MB
#
# Model Structure:
# MultitaskDebateGNN(
#   (convs): ModuleList(
#     (0): SAGEConv(384, 256, aggr=mean)
#     (1): SAGEConv(256, 256, aggr=mean)
#     (2): ECCConv(256, 128)
#   )
#   (norms): ModuleList(
#     (0-1): 2 x LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (activation): GELU(approximate='none')
#   (dropout): Dropout(p=0.15, inplace=False)
#   (skip): Linear(in_features=384, out_features=128, bias=True)
#   (link_head): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.15, inplace=False)
#     (3): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (edge_head): Sequential(
#     (0): Linear(in_features=256, out_features=256, bias=True)
#     (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.15, inplace=False)
#     (4): Linear(in_features=256, out_features=4, bias=True)
#   )
# )

# %%
import numpy as np
import pandas as pd
import torch
from collections import defaultdict
from copy import deepcopy


def gap_ablation_test_means(
    gaps,
    repeats=1,
    train_args_base=None,
    model_args=None,
    graph_data=None,
    seed_base=42,
    save_csv="results/ablation/val_temporal_gaps_test_scores.csv",
):
    """
    Run gap ablation, average test metrics across folds and repeats.
    Produces a table with per-gap metric means in the specified column order.
    """
    assert train_args_base is not None and model_args is not None and graph_data is not None

    records = {g: defaultdict(list) for g in gaps}

    for g in gaps:
        for r in range(repeats):
            seed = seed_base + r
            np.random.seed(seed)
            torch.manual_seed(seed)
            if torch.cuda.is_available():
                torch.cuda.manual_seed_all(seed)

            ta = deepcopy(train_args_base)
            ta["val_gap_n"] = int(g)
            print(f"[gap={g}] repeat {r+1}/{repeats} seed={seed}")
            _, results, _ = run_cv_training(
                graph_data=graph_data,
                model_args=model_args,
                train_args=ta,
                model_class=MultitaskDebateGNN,
                live_plot=False,
            )

            if not results:
                continue

            all_fold_dicts = list(results.values()) if isinstance(results, dict) else list(results)
            metric_names = sorted({k for d in all_fold_dicts for k in d.keys()})
            for m in metric_names:
                vals = [d.get(m, np.nan) for d in all_fold_dicts]
                vals = [float(x) for x in vals if x is not None]
                mean_across_folds = np.nan if len(vals) == 0 else float(np.nanmean(vals))
                records[g][m].append(mean_across_folds)

    # Desired column order
    desired_order = [
        "gap",
        "link_auc_mean",
        "conf_mae_mean",
        "conf_nll_mean",
        "stance_nll_mean",
        "stance_kl_mean"
    ]

    # Build DataFrame with mean across repeats (no std)
    rows = []
    all_metrics = sorted({m for rec in records.values() for m in rec.keys()})
    for g in gaps:
        row = {"gap": g}
        for m in all_metrics:
            arr = np.array(records[g].get(m, []), dtype=float)
            mean_over_repeats = float(np.nan) if arr.size == 0 else float(np.nanmean(arr))
            row[f"{m}_mean"] = mean_over_repeats
        rows.append(row)

    df = pd.DataFrame(rows)

    # Ensure all desired columns exist and reorder
    for col in desired_order:
        if col not in df.columns:
            df[col] = np.nan
    df = df[desired_order]

    # Format to 3 digits
    pd.options.display.float_format = "{:0.3f}".format

    print("\nGap ablation — test metrics (means across folds & repeats):")
    display(df)

    try:
        df.to_csv(save_csv, index=False, float_format="%.3f")
        print(f"Saved summary CSV to: {save_csv}")
    except Exception as e:
        print(f"Could not save CSV: {e}")

    return df, records


# Run and save results
df_means, raw = gap_ablation_test_means(
    gaps=[0,1,2,3], repeats=1, 
    train_args_base=TRAIN_ARGS, model_args=MODEL_ARGS, graph_data=PYG_GRAPHS)
# Out:
# [gap=0] repeat 1/1 seed=42
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: full
#   - Task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#   - Tasks: Link, Confidence, Stance
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,084 nodes | 938 edges | Avg: 93.8 edges/graph
#    + Stance Dist: [0.322, 0.239, 0.439] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,291 nodes | 4,297 edges | Avg: 165.3 edges/graph
#    + Stance Dist: [0.407, 0.283, 0.310] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 7,302 nodes | 8,143 edges | Avg: 904.8 edges/graph
#    + Stance Dist: [0.360, 0.216, 0.424] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,417 nodes | 7,598 edges | Avg: 844.2 edges/graph
#    + Stance Dist: [0.401, 0.246, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,380
#   - Total edges: 35,556
#   - Avg nodes/graph: 316.6
#   - Avg edges/graph: 461.8
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.396, 0.262, 0.343] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 53 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.383, 0.242, 0.375] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.078, neutral:-0.201, agree:+0.099
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.574, σ=0.387
#   - Stance dist: [0.221, 0.270, 0.508] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.008, neutral:-0.035, agree:+0.037
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0014)
#   - Stance weights:  [2.610, 4.139, 2.665]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.8425 | Link=18.9173 | Conf=0.0432 | Stance=0.7288
#   - Val:   Total=5.3478 | Link=10.1121 | Conf=0.0494 | Stance=0.5388
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.6494 | Link=0.8270 | Conf=0.0317 | Stance=0.4392
#   - Val:   Total=0.6353 | Link=1.0099 | Conf=0.0366 | Stance=0.2482
#   - Uncertainty: Link=1.000 | Conf=0.987 | Stance=0.985
#   - LR: 1.00e-04
#   Early stopping at epoch 24
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.7986
#    - Conf Mae: 0.3383
#    - Conf Nll: 0.7028
#    - Stance Nll: 0.8415
#    - Stance Kl: 0.8117
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.398, 0.261, 0.340] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.085, neutral:-0.185, agree:+0.083
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0022)
#   - Stance weights:  [2.511, 3.826, 2.937]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.9412 | Link=16.9304 | Conf=0.0422 | Stance=0.7225
#   - Val:   Total=3.8905 | Link=7.1915 | Conf=0.0409 | Stance=0.5525
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#   Early stopping at epoch 15
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.8957
#    - Conf Mae: 0.3407
#    - Conf Nll: 0.7291
#    - Stance Nll: 0.4588
#    - Stance Kl: 0.4530
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 50 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.375
#   - Stance dist: [0.395, 0.258, 0.348] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.082, neutral:-0.183, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0021)
#   - Stance weights:  [2.534, 3.881, 2.876]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.0923 | Link=19.1542 | Conf=0.0417 | Stance=0.7151
#   - Val:   Total=5.5077 | Link=10.4291 | Conf=0.0390 | Stance=0.5520
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.8492 | Link=1.0768 | Conf=0.0333 | Stance=0.5855
#   - Val:   Total=1.0048 | Link=1.5179 | Conf=0.0318 | Stance=0.4815
#   - Uncertainty: Link=1.004 | Conf=0.987 | Stance=0.986
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.8947
#    - Conf Mae: 0.3485
#    - Conf Nll: 0.7187
#    - Stance Nll: 0.5711
#    - Stance Kl: 0.5691
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 67 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.518, σ=0.374
#   - Stance dist: [0.407, 0.274, 0.319] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.089, neutral:-0.176, agree:+0.074
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0028)
#   - Stance weights:  [2.456, 3.647, 3.138]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.6617 | Link=16.2655 | Conf=0.0430 | Stance=0.7242
#   - Val:   Total=3.6010 | Link=6.6123 | Conf=0.0404 | Stance=0.5529
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7356 | Link=0.9599 | Conf=0.0322 | Stance=0.4787
#   - Val:   Total=0.9603 | Link=1.4837 | Conf=0.0326 | Stance=0.4306
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#   Early stopping at epoch 21
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.8956
#    - Conf Mae: 0.3441
#    - Conf Nll: 0.7205
#    - Stance Nll: 0.6026
#    - Stance Kl: 0.6002
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (0 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 67 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.516, σ=0.374
#   - Stance dist: [0.395, 0.265, 0.340] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.089, neutral:-0.185, agree:+0.080
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0032)
#   - Stance weights:  [2.533, 3.774, 2.939]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.2683 | Link=17.4911 | Conf=0.0420 | Stance=0.7248
#   - Val:   Total=4.3450 | Link=8.1026 | Conf=0.0399 | Stance=0.5519
#   - Uncertainty: Link=1.001 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7172 | Link=0.9197 | Conf=0.0319 | Stance=0.4817
#   - Val:   Total=0.9591 | Link=1.4782 | Conf=0.0324 | Stance=0.4337
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.9072
#    - Conf Mae: 0.3494
#    - Conf Nll: 0.7166
#    - Stance Nll: 0.5790
#    - Stance Kl: 0.5774
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.7986
#      - Conf Mae          : 0.3383
#      - Conf Nll          : 0.7028
#      - Stance Nll        : 0.8415
#      - Stance Kl         : 0.8117
#   Subreddit 1:
#      - Link Auc          : 0.8957
#      - Conf Mae          : 0.3407
#      - Conf Nll          : 0.7291
#      - Stance Nll        : 0.4588
#      - Stance Kl         : 0.4530
#   Subreddit 2:
#      - Link Auc          : 0.8947
#      - Conf Mae          : 0.3485
#      - Conf Nll          : 0.7187
#      - Stance Nll        : 0.5711
#      - Stance Kl         : 0.5691
#   Subreddit 3:
#      - Link Auc          : 0.8956
#      - Conf Mae          : 0.3441
#      - Conf Nll          : 0.7205
#      - Stance Nll        : 0.6026
#      - Stance Kl         : 0.6002
#   Subreddit 4:
#      - Link Auc          : 0.9072
#      - Conf Mae          : 0.3494
#      - Conf Nll          : 0.7166
#      - Stance Nll        : 0.5790
#      - Stance Kl         : 0.5774
#
# *** Average Test Performance ***
#   - Conf Mae            : 0.3442
#   - Conf Nll            : 0.7175
#   - Link Auc            : 0.8784
#   - Stance Kl           : 0.6023
#   - Stance Nll          : 0.6106
# [gap=1] repeat 1/1 seed=42
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: full
#   - Task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#   - Tasks: Link, Confidence, Stance
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,084 nodes | 938 edges | Avg: 93.8 edges/graph
#    + Stance Dist: [0.322, 0.239, 0.439] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,291 nodes | 4,297 edges | Avg: 165.3 edges/graph
#    + Stance Dist: [0.407, 0.283, 0.310] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 7,302 nodes | 8,143 edges | Avg: 904.8 edges/graph
#    + Stance Dist: [0.360, 0.216, 0.424] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,417 nodes | 7,598 edges | Avg: 844.2 edges/graph
#    + Stance Dist: [0.401, 0.246, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,380
#   - Total edges: 35,556
#   - Avg nodes/graph: 316.6
#   - Avg edges/graph: 461.8
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.396, 0.262, 0.343] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 52 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 1 timestep(s) skipped: [8]
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.383, 0.242, 0.375] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.078, neutral:-0.200, agree:+0.099
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.574, σ=0.387
#   - Stance dist: [0.221, 0.270, 0.508] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.008, neutral:-0.035, agree:+0.037
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0014)
#   - Stance weights:  [2.609, 4.140, 2.666]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.8894 | Link=19.0115 | Conf=0.0432 | Stance=0.7282
#   - Val:   Total=5.4305 | Link=10.2736 | Conf=0.0493 | Stance=0.5427
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.6543 | Link=0.8447 | Conf=0.0319 | Stance=0.4307
#   - Val:   Total=0.7846 | Link=1.2987 | Conf=0.0394 | Stance=0.2550
#   - Uncertainty: Link=1.000 | Conf=0.987 | Stance=0.985
#   - LR: 1.00e-04
#   Early stopping at epoch 23
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.7892
#    - Conf Mae: 0.3380
#    - Conf Nll: 0.7029
#    - Stance Nll: 0.8650
#    - Stance Kl: 0.8352
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 65 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.376
#   - Stance dist: [0.399, 0.260, 0.341] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.085, neutral:-0.185, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0021)
#   - Stance weights:  [2.507, 3.842, 2.934]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.0210 | Link=17.0875 | Conf=0.0422 | Stance=0.7219
#   - Val:   Total=4.0132 | Link=7.4370 | Conf=0.0403 | Stance=0.5531
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7390 | Link=0.9674 | Conf=0.0321 | Stance=0.4769
#   - Val:   Total=1.0124 | Link=1.5938 | Conf=0.0320 | Stance=0.4250
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#   Early stopping at epoch 23
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.8783
#    - Conf Mae: 0.3476
#    - Conf Nll: 0.6951
#    - Stance Nll: 0.4231
#    - Stance Kl: 0.4173
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 49 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.520, σ=0.375
#   - Stance dist: [0.395, 0.256, 0.348] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.081, neutral:-0.183, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0020)
#   - Stance weights:  [2.529, 3.900, 2.872]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.1440 | Link=19.2630 | Conf=0.0417 | Stance=0.7151
#   - Val:   Total=5.6020 | Link=10.6169 | Conf=0.0392 | Stance=0.5527
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.8316 | Link=1.0432 | Conf=0.0330 | Stance=0.5834
#   - Val:   Total=1.0268 | Link=1.5604 | Conf=0.0327 | Stance=0.4818
#   - Uncertainty: Link=1.004 | Conf=0.987 | Stance=0.987
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.8946
#    - Conf Mae: 0.3479
#    - Conf Nll: 0.7240
#    - Stance Nll: 0.5962
#    - Stance Kl: 0.5942
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.374
#   - Stance dist: [0.408, 0.273, 0.319] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.088, neutral:-0.176, agree:+0.075
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0028)
#   - Stance weights:  [2.450, 3.662, 3.138]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.7242 | Link=16.3895 | Conf=0.0431 | Stance=0.7239
#   - Val:   Total=3.6995 | Link=6.8090 | Conf=0.0405 | Stance=0.5533
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7359 | Link=0.9640 | Conf=0.0321 | Stance=0.4754
#   - Val:   Total=0.9472 | Link=1.4574 | Conf=0.0325 | Stance=0.4305
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.9208
#    - Conf Mae: 0.3435
#    - Conf Nll: 0.6987
#    - Stance Nll: 0.5843
#    - Stance Kl: 0.5819
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (1 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 66 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=1): Subreddit 0 timestep(s) skipped: [21]
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.517, σ=0.374
#   - Stance dist: [0.396, 0.264, 0.341] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.089, neutral:-0.186, agree:+0.081
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0031)
#   - Stance weights:  [2.528, 3.792, 2.935]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.3182 | Link=17.5910 | Conf=0.0419 | Stance=0.7248
#   - Val:   Total=4.3862 | Link=8.1833 | Conf=0.0400 | Stance=0.5535
#   - Uncertainty: Link=1.001 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7209 | Link=0.9339 | Conf=0.0321 | Stance=0.4764
#   - Val:   Total=0.9083 | Link=1.3819 | Conf=0.0316 | Stance=0.4292
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.9124
#    - Conf Mae: 0.3433
#    - Conf Nll: 0.7154
#    - Stance Nll: 0.5561
#    - Stance Kl: 0.5545
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.7892
#      - Conf Mae          : 0.3380
#      - Conf Nll          : 0.7029
#      - Stance Nll        : 0.8650
#      - Stance Kl         : 0.8352
#   Subreddit 1:
#      - Link Auc          : 0.8783
#      - Conf Mae          : 0.3476
#      - Conf Nll          : 0.6951
#      - Stance Nll        : 0.4231
#      - Stance Kl         : 0.4173
#   Subreddit 2:
#      - Link Auc          : 0.8946
#      - Conf Mae          : 0.3479
#      - Conf Nll          : 0.7240
#      - Stance Nll        : 0.5962
#      - Stance Kl         : 0.5942
#   Subreddit 3:
#      - Link Auc          : 0.9208
#      - Conf Mae          : 0.3435
#      - Conf Nll          : 0.6987
#      - Stance Nll        : 0.5843
#      - Stance Kl         : 0.5819
#   Subreddit 4:
#      - Link Auc          : 0.9124
#      - Conf Mae          : 0.3433
#      - Conf Nll          : 0.7154
#      - Stance Nll        : 0.5561
#      - Stance Kl         : 0.5545
#
# *** Average Test Performance ***
#   - Conf Mae            : 0.3441
#   - Conf Nll            : 0.7072
#   - Link Auc            : 0.8791
#   - Stance Kl           : 0.5966
#   - Stance Nll          : 0.6049
# [gap=2] repeat 1/1 seed=42
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: full
#   - Task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#   - Tasks: Link, Confidence, Stance
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,084 nodes | 938 edges | Avg: 93.8 edges/graph
#    + Stance Dist: [0.322, 0.239, 0.439] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,291 nodes | 4,297 edges | Avg: 165.3 edges/graph
#    + Stance Dist: [0.407, 0.283, 0.310] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 7,302 nodes | 8,143 edges | Avg: 904.8 edges/graph
#    + Stance Dist: [0.360, 0.216, 0.424] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,417 nodes | 7,598 edges | Avg: 844.2 edges/graph
#    + Stance Dist: [0.401, 0.246, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,380
#   - Total edges: 35,556
#   - Avg nodes/graph: 316.6
#   - Avg edges/graph: 461.8
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.396, 0.262, 0.343] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 51 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 1 timestep(s) skipped: [7, 8]
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.383, 0.242, 0.375] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.078, neutral:-0.200, agree:+0.099
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.574, σ=0.387
#   - Stance dist: [0.221, 0.270, 0.508] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.008, neutral:-0.035, agree:+0.037
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0014)
#   - Stance weights:  [2.608, 4.140, 2.667]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.9415 | Link=19.1157 | Conf=0.0435 | Stance=0.7280
#   - Val:   Total=5.5127 | Link=10.4348 | Conf=0.0491 | Stance=0.5461
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#   Early stopping at epoch 15
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.7055
#    - Conf Mae: 0.3094
#    - Conf Nll: 0.7297
#    - Stance Nll: 0.8707
#    - Stance Kl: 0.8409
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 64 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 0 timestep(s) skipped: [20, 21]
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.523, σ=0.376
#   - Stance dist: [0.400, 0.258, 0.342] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.086, neutral:-0.189, agree:+0.086
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0021)
#   - Stance weights:  [2.502, 3.871, 2.924]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.0674 | Link=17.1777 | Conf=0.0423 | Stance=0.7227
#   - Val:   Total=4.0709 | Link=7.5508 | Conf=0.0405 | Stance=0.5544
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7276 | Link=0.9403 | Conf=0.0320 | Stance=0.4800
#   - Val:   Total=0.9505 | Link=1.4681 | Conf=0.0308 | Stance=0.4271
#   - Uncertainty: Link=1.002 | Conf=0.985 | Stance=0.984
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.9045
#    - Conf Mae: 0.3452
#    - Conf Nll: 0.6821
#    - Stance Nll: 0.4294
#    - Stance Kl: 0.4235
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 48 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 0 timestep(s) skipped: [20, 21]
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.396, 0.254, 0.350] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.083, neutral:-0.187, agree:+0.086
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0020)
#   - Stance weights:  [2.524, 3.937, 2.858]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.2009 | Link=19.3827 | Conf=0.0419 | Stance=0.7148
#   - Val:   Total=5.6969 | Link=10.8060 | Conf=0.0393 | Stance=0.5531
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.8214 | Link=1.0275 | Conf=0.0328 | Stance=0.5787
#   - Val:   Total=1.0820 | Link=1.6717 | Conf=0.0334 | Stance=0.4800
#   - Uncertainty: Link=1.004 | Conf=0.988 | Stance=0.987
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.9002
#    - Conf Mae: 0.3457
#    - Conf Nll: 0.7192
#    - Stance Nll: 0.5792
#    - Stance Kl: 0.5772
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 65 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 0 timestep(s) skipped: [20, 21]
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.521, σ=0.374
#   - Stance dist: [0.410, 0.271, 0.319] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.090, neutral:-0.180, agree:+0.077
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0027)
#   - Stance weights:  [2.440, 3.687, 3.135]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.7716 | Link=16.4880 | Conf=0.0431 | Stance=0.7233
#   - Val:   Total=3.7502 | Link=6.9088 | Conf=0.0405 | Stance=0.5548
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7161 | Link=0.9240 | Conf=0.0319 | Stance=0.4747
#   - Val:   Total=0.9117 | Link=1.3898 | Conf=0.0307 | Stance=0.4283
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.9132
#    - Conf Mae: 0.3459
#    - Conf Nll: 0.6937
#    - Stance Nll: 0.5819
#    - Stance Kl: 0.5796
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (2 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 65 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=2): Subreddit 0 timestep(s) skipped: [20, 21]
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.518, σ=0.374
#   - Stance dist: [0.396, 0.261, 0.342] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.090, neutral:-0.190, agree:+0.083
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0030)
#   - Stance weights:  [2.522, 3.826, 2.923]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.3684 | Link=17.6889 | Conf=0.0421 | Stance=0.7253
#   - Val:   Total=4.4819 | Link=8.3733 | Conf=0.0403 | Stance=0.5547
#   - Uncertainty: Link=1.001 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7232 | Link=0.9355 | Conf=0.0321 | Stance=0.4792
#   - Val:   Total=0.9583 | Link=1.4770 | Conf=0.0326 | Stance=0.4329
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.9160
#    - Conf Mae: 0.3464
#    - Conf Nll: 0.7132
#    - Stance Nll: 0.5688
#    - Stance Kl: 0.5672
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.7055
#      - Conf Mae          : 0.3094
#      - Conf Nll          : 0.7297
#      - Stance Nll        : 0.8707
#      - Stance Kl         : 0.8409
#   Subreddit 1:
#      - Link Auc          : 0.9045
#      - Conf Mae          : 0.3452
#      - Conf Nll          : 0.6821
#      - Stance Nll        : 0.4294
#      - Stance Kl         : 0.4235
#   Subreddit 2:
#      - Link Auc          : 0.9002
#      - Conf Mae          : 0.3457
#      - Conf Nll          : 0.7192
#      - Stance Nll        : 0.5792
#      - Stance Kl         : 0.5772
#   Subreddit 3:
#      - Link Auc          : 0.9132
#      - Conf Mae          : 0.3459
#      - Conf Nll          : 0.6937
#      - Stance Nll        : 0.5819
#      - Stance Kl         : 0.5796
#   Subreddit 4:
#      - Link Auc          : 0.9160
#      - Conf Mae          : 0.3464
#      - Conf Nll          : 0.7132
#      - Stance Nll        : 0.5688
#      - Stance Kl         : 0.5672
#
# *** Average Test Performance ***
#   - Conf Mae            : 0.3385
#   - Conf Nll            : 0.7076
#   - Link Auc            : 0.8679
#   - Stance Kl           : 0.5977
#   - Stance Nll          : 0.6060
# [gap=3] repeat 1/1 seed=42
#
# Dataset Overview:
#   - Total graphs: 77
#   - Device: cuda
#   - Training mode: full
#   - Task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#   - Tasks: Link, Confidence, Stance
#    + Subreddit 0: 23 graphs | 4,286 nodes | 14,580 edges | Avg: 633.9 edges/graph
#    + Stance Dist: [0.414, 0.290, 0.296] (disagree/neutral/agree)
#    + Subreddit 1: 10 graphs | 1,084 nodes | 938 edges | Avg: 93.8 edges/graph
#    + Stance Dist: [0.322, 0.239, 0.439] (disagree/neutral/agree)
#    + Subreddit 2: 26 graphs | 4,291 nodes | 4,297 edges | Avg: 165.3 edges/graph
#    + Stance Dist: [0.407, 0.283, 0.310] (disagree/neutral/agree)
#    + Subreddit 3: 9 graphs | 7,302 nodes | 8,143 edges | Avg: 904.8 edges/graph
#    + Stance Dist: [0.360, 0.216, 0.424] (disagree/neutral/agree)
#    + Subreddit 4: 9 graphs | 7,417 nodes | 7,598 edges | Avg: 844.2 edges/graph
#    + Stance Dist: [0.401, 0.246, 0.353] (disagree/neutral/agree)
#
# Global Statistics:
#   - Total nodes: 24,380
#   - Total edges: 35,556
#   - Avg nodes/graph: 316.6
#   - Avg edges/graph: 461.8
#
# Global Edge Attribute Analysis:
#
# Edge Attribute (Full Dataset):
#   - Confidence: μ=0.521, σ=0.375
#   - Stance dist: [0.396, 0.262, 0.343] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.084, neutral:-0.184, agree:+0.084
#
# ==================================================
# Training for Test Subreddit: 0
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 1 → 50 graphs
#     Train subreddits: [2, 3, 4, '1 (partial)']
#   - Validation: Subreddit 1 latest timestep(s): [9] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 1 timestep(s) skipped: [6, 7, 8]
#   - Testing: Subreddit 0 → 23 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.537, σ=0.381
#   - Stance dist: [0.384, 0.241, 0.375] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.077, neutral:-0.200, agree:+0.099
#
# Edge Attribute (Validation (Sub 1)):
#   - Confidence: μ=0.574, σ=0.387
#   - Stance dist: [0.221, 0.270, 0.508] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.008, neutral:-0.035, agree:+0.037
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0014)
#   - Stance weights:  [2.607, 4.143, 2.667]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.9910 | Link=19.2150 | Conf=0.0435 | Stance=0.7275
#   - Val:   Total=5.5939 | Link=10.5962 | Conf=0.0488 | Stance=0.5473
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.6617 | Link=0.8456 | Conf=0.0324 | Stance=0.4443
#   - Val:   Total=0.5436 | Link=0.8409 | Conf=0.0345 | Stance=0.2355
#   - Uncertainty: Link=1.000 | Conf=0.987 | Stance=0.986
#   - LR: 1.00e-04
#   Early stopping at epoch 25
#
# Final Evaluation on Test Subreddit 0:
#
# Test Metrics for 0:
#    - Link Auc: 0.8029
#    - Conf Mae: 0.3340
#    - Conf Nll: 0.7025
#    - Stance Nll: 0.8690
#    - Stance Kl: 0.8392
#
# ==================================================
# Training for Test Subreddit: 1
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 63 graphs
#     Train subreddits: [2, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 0 timestep(s) skipped: [19, 20, 21]
#   - Testing: Subreddit 1 → 10 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.523, σ=0.376
#   - Stance dist: [0.401, 0.257, 0.342] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.085, neutral:-0.190, agree:+0.087
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0020)
#   - Stance weights:  [2.496, 3.888, 2.923]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.1253 | Link=17.2849 | Conf=0.0423 | Stance=0.7225
#   - Val:   Total=4.1322 | Link=7.6725 | Conf=0.0409 | Stance=0.5550
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7034 | Link=0.8959 | Conf=0.0319 | Stance=0.4766
#   - Val:   Total=0.9058 | Link=1.3845 | Conf=0.0310 | Stance=0.4205
#   - Uncertainty: Link=1.002 | Conf=0.985 | Stance=0.984
#   - LR: 1.00e-04
#   Early stopping at epoch 22
#
# Final Evaluation on Test Subreddit 1:
#
# Test Metrics for 1:
#    - Link Auc: 0.8961
#    - Conf Mae: 0.3461
#    - Conf Nll: 0.6907
#    - Stance Nll: 0.4223
#    - Stance Kl: 0.4165
#
# ==================================================
# Training for Test Subreddit: 2
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 47 graphs
#     Train subreddits: [1, 3, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 0 timestep(s) skipped: [19, 20, 21]
#   - Testing: Subreddit 2 → 26 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.522, σ=0.376
#   - Stance dist: [0.397, 0.253, 0.350] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.082, neutral:-0.189, agree:+0.088
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0019)
#   - Stance weights:  [2.518, 3.958, 2.855]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=10.2396 | Link=19.4661 | Conf=0.0419 | Stance=0.7150
#   - Val:   Total=5.7701 | Link=10.9524 | Conf=0.0391 | Stance=0.5534
#   - Uncertainty: Link=1.000 | Conf=1.000 | Stance=1.000
#   - LR: 1.00e-04
#   Early stopping at epoch 19
#
# Final Evaluation on Test Subreddit 2:
#
# Test Metrics for 2:
#    - Link Auc: 0.8584
#    - Conf Mae: 0.3396
#    - Conf Nll: 0.7893
#    - Stance Nll: 0.8157
#    - Stance Kl: 0.8137
#
# ==================================================
# Training for Test Subreddit: 3
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 64 graphs
#     Train subreddits: [1, 2, 4, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 0 timestep(s) skipped: [19, 20, 21]
#   - Testing: Subreddit 3 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.522, σ=0.375
#   - Stance dist: [0.411, 0.270, 0.318] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.089, neutral:-0.181, agree:+0.078
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0026)
#   - Stance weights:  [2.431, 3.700, 3.141]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=8.8272 | Link=16.5943 | Conf=0.0433 | Stance=0.7230
#   - Val:   Total=3.8161 | Link=7.0397 | Conf=0.0407 | Stance=0.5554
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7188 | Link=0.9378 | Conf=0.0318 | Stance=0.4663
#   - Val:   Total=1.0063 | Link=1.5774 | Conf=0.0323 | Stance=0.4283
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#   Early stopping at epoch 21
#
# Final Evaluation on Test Subreddit 3:
#
# Test Metrics for 3:
#    - Link Auc: 0.9010
#    - Conf Mae: 0.3437
#    - Conf Nll: 0.7082
#    - Stance Nll: 0.5951
#    - Stance Kl: 0.5927
#
# ==================================================
# Training for Test Subreddit: 4
# ==================================================
#
# Data Split with Temporal Gap (3 timesteps):
#   - Training: 3 subreddits + early timesteps from val 0 → 64 graphs
#     Train subreddits: [1, 2, 3, '0 (partial)']
#   - Validation: Subreddit 0 latest timestep(s): [22] → 1 graph(s)
#   - Temporal Gap (g=3): Subreddit 0 timestep(s) skipped: [19, 20, 21]
#   - Testing: Subreddit 4 → 9 graphs
#
# Edge Attribute (Training):
#   - Confidence: μ=0.519, σ=0.375
#   - Stance dist: [0.398, 0.260, 0.342] (disagree/neutral/agree)
#   - Confidence correlations: disagree:+0.090, neutral:-0.192, agree:+0.084
#
# Edge Attribute (Validation (Sub 0)):
#   - Confidence: μ=0.452, σ=0.351
#   - Stance dist: [0.352, 0.331, 0.316] (disagree/neutral/agree)
#   - Confidence correlations: disagree:-0.004, neutral:-0.050, agree:+0.055
#
# Loss Balancing:
#   - Link pos_weight: 50.000 (pos/neg ratio: 0.0029)
#   - Stance weights:  [2.516, 3.845, 2.921]
#
# Model Configs:
#   - Total parameters: 4,741,704 (trainable: 4,741,704)
#   - Base LR: 1.00e-04
#   - Log-var LR: 1.00e-05
#   - Custom task weights: {'link': 1.0, 'conf': 1.0, 'stance': 1.0}
#
# *** BEGIN TRAINING ***
#   - Max epochs: 30
#   - Early stopping patience: 6 epochs
#   - Negative sampling ratio: 0.50
#   - Temporal regularization weight: 0.100
#
# Epoch   0:
#   - Train: Total=9.4234 | Link=17.8008 | Conf=0.0421 | Stance=0.7256
#   - Val:   Total=4.5588 | Link=8.5275 | Conf=0.0401 | Stance=0.5546
#   - Uncertainty: Link=1.000 | Conf=0.999 | Stance=0.999
#   - LR: 1.00e-04
#
# Epoch  20:
#   - Train: Total=0.7482 | Link=0.9806 | Conf=0.0323 | Stance=0.4825
#   - Val:   Total=0.9925 | Link=1.5501 | Conf=0.0328 | Stance=0.4284
#   - Uncertainty: Link=1.003 | Conf=0.985 | Stance=0.983
#   - LR: 1.00e-04
#   Early stopping at epoch 21
#
# Final Evaluation on Test Subreddit 4:
#
# Test Metrics for 4:
#    - Link Auc: 0.8903
#    - Conf Mae: 0.3503
#    - Conf Nll: 0.7104
#    - Stance Nll: 0.5775
#    - Stance Kl: 0.5759
#
# *** Per-Fold Results ***
#   Subreddit 0:
#      - Link Auc          : 0.8029
#      - Conf Mae          : 0.3340
#      - Conf Nll          : 0.7025
#      - Stance Nll        : 0.8690
#      - Stance Kl         : 0.8392
#   Subreddit 1:
#      - Link Auc          : 0.8961
#      - Conf Mae          : 0.3461
#      - Conf Nll          : 0.6907
#      - Stance Nll        : 0.4223
#      - Stance Kl         : 0.4165
#   Subreddit 2:
#      - Link Auc          : 0.8584
#      - Conf Mae          : 0.3396
#      - Conf Nll          : 0.7893
#      - Stance Nll        : 0.8157
#      - Stance Kl         : 0.8137
#   Subreddit 3:
#      - Link Auc          : 0.9010
#      - Conf Mae          : 0.3437
#      - Conf Nll          : 0.7082
#      - Stance Nll        : 0.5951
#      - Stance Kl         : 0.5927
#   Subreddit 4:
#      - Link Auc          : 0.8903
#      - Conf Mae          : 0.3503
#      - Conf Nll          : 0.7104
#      - Stance Nll        : 0.5775
#      - Stance Kl         : 0.5759
#
# *** Average Test Performance ***
#   - Conf Mae            : 0.3427
#   - Conf Nll            : 0.7202
#   - Link Auc            : 0.8698
#   - Stance Kl           : 0.6476
#   - Stance Nll          : 0.6559
# Gap ablation — test metrics (means across folds & repeats):
#    gap  link_auc_mean  conf_mae_mean  conf_nll_mean  stance_nll_mean  \
# 0    0          0.878          0.344          0.718            0.611
# 1    1          0.879          0.344          0.707            0.605
# 2    2          0.868          0.339          0.708            0.606
# 3    3          0.870          0.343          0.720            0.656
#
#    stance_kl_mean
# 0           0.602
# 1           0.597
# 2           0.598
# 3           0.648
# Saved summary CSV to: results/gap_ablation_test_means.csv
